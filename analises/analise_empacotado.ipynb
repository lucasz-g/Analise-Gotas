# %%
import pandas as pd
import plotly.express as px

# %%
dados = pd.read_excel('../Empacotado.xlsx')

# %%
dados
# Out:
#      Data Wheaton Dia  Data Wheaton Mês  Data Wheaton Ano  Corrida  \
# 0                13.0               6.0            2024.0   193882
# 1                12.0               6.0            2024.0   193882
# 2                11.0               6.0            2024.0   193882
# 3                 1.0               5.0            2024.0   193694
# 4                14.0               6.0            2024.0   193882
# ..                ...               ...               ...      ...
# 215              17.0               6.0            2024.0   193533
# 216              20.0               3.0            2024.0   192384
# 217               NaN               NaN               NaN   193207
# 218               NaN               NaN               NaN   193462
# 219              24.0               3.0            2024.0   192305
#
#     Processo Plan Maquina  Secao             Item  \
# 0      DUPLA GOTA      B1      8  C1268.0000.R001
# 1      DUPLA GOTA      B1      8  C1268.0000.R001
# ...

# %%
empacotado_por_ordem = dados.groupby('Corrida')[['Qtd Empacotado']].sum()

# %%
empacotado_por_ordem
# Out:
#          Qtd Empacotado
# Corrida
# 192305                0
# 192384                0
# 192970           384300
# 193112           207900
# 193164          1029000
# 193206           181440
# 193207           406080
# 193208           104500
# 193209           194250
# 193342          1459500
# 193368           627200
# 193459            86400
# 193462           262080
# 193463           365760
# 193533           595200
# 193535           182400
# 193537           149600
# 193594           588000
# 193619           330750
# 193671           148050
# 193686           180600
# 193688           105600
# 193689           103680
# 193692           145200
# 193694           415200
# 193782           889600
# 193783           107100
# 193784           794200
# 193852           336000
# 193882           781200
# 193937           141120
# 193972           138600
# 193973           295200
# 194029           248640
# 194057           192500
# 194113           165000
# 194121           323400
