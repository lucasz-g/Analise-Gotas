# %%
import pandas as pd
import matplotlib.pyplot  as plt
import numpy as np
import plotly.express as px

# %%
dados = pd.read_excel('../dados/df_combinado_janeiro_formatado.xlsx')
df = pd.DataFrame(dados)

# %% [markdown]
# # Tratamento e Transformação

# %%
df
# Out:
#     Ordem de prod Data de prod  Gotas cortadas (toneladas)  Perdas AQ  \
# 0          192970   2024-01-03                     20.9484     8.7433
# 1          192970   2024-01-04                     21.0216     4.8770
# 2          192970   2024-01-05                     21.4492     4.5696
# 3          192970   2024-01-06                     21.5256     4.2016
# 4          192970   2024-01-07                     21.4387     6.9136
# 5          192970   2024-01-08                     21.5064     1.9749
# 6          192970   2024-01-09                     21.5235     3.0861
# 7          192970   2024-01-10                     21.4267     3.2898
# 8          192970   2024-01-11                      7.9468     1.1851
# 9          193112   2024-01-01                     21.8905     1.5552
# 10         193112   2024-01-02                     21.8574     1.2168
# 11         193112   2024-01-03                      0.9849     0.1345
# ...

# %% [markdown]
# ###

# %% [markdown]
# ### Transformando DataFrame para multiíndices 'Ordem de produção' e 'Data de produção'

# %%
df = df.set_index(['Ordem de prod', 'Data de prod'])
df
# Out:
#                             Gotas cortadas (toneladas)  Perdas AQ  \
# Ordem de prod Data de prod
# 192970        2024-01-03                       20.9484     8.7433
#               2024-01-04                       21.0216     4.8770
#               2024-01-05                       21.4492     4.5696
#               2024-01-06                       21.5256     4.2016
#               2024-01-07                       21.4387     6.9136
#               2024-01-08                       21.5064     1.9749
#               2024-01-09                       21.5235     3.0861
#               2024-01-10                       21.4267     3.2898
#               2024-01-11                        7.9468     1.1851
# 193112        2024-01-01                       21.8905     1.5552
#               2024-01-02                       21.8574     1.2168
#               2024-01-03                        0.9849     0.1345
# 193164        2024-01-11                       12.4944     5.0985
# ...
